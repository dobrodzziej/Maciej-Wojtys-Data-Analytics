# %%
from cmdstanpy import CmdStanModel


import arviz as az
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets, linear_model

# %% [markdown]
# We will generate fake data, that will simulate dataset of 100 outputs from 200 dimensional linear model along with appropriate predictors. Our goal will be estimation of the parameters of the model.

# %%
data_genetator = CmdStanModel(stan_file = 'generate_data.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
I= 6
N= 6
DoB= 18.01 # Date of birth day and month
seed=int(DoB*1e4+100*I+N)
print(seed)
generated_data = data_genetator.sample(chains=1, iter_sampling=1, iter_warmup=0, fixed_param=True,seed=seed)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# 180706
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %% [markdown]
# ### Coefficients of linear model
# Only few of beta coefficients are significantly greater than 0.

# %%
beta_s = generated_data.stan_variable('beta')

# %%
plt.stairs(generated_data.stan_variable('beta')[0])
plt.show()

# %% [markdown]
# This is an issue called sparsity. We will try to exploit that when infering the results via changing the prior structure.

# %% [markdown]
# ### Model 1 - uniform prior for beta

# %%
model_uniform = CmdStanModel(stan_file = 'model1.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data_for_inference = {'N':100,
                      'M':200,
                      'X':generated_data.stan_variable('X')[0],
                      'y':generated_data.stan_variable('y')[0]
                      }

# %%
fit_unf = model_uniform.sample(data=data_for_inference,seed=seed)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
#
#
# chain 1 |▉         | 00:06 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:12 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:19 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |██▎       | 00:27 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 00:34 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▏      | 00:41 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |███▋      | 00:48 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
# chain 1 |████      | 00:56 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |████▌     | 01:04 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
#
# chain 1 |█████     | 01:11 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
# chain 1 |█████▉    | 01:18 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▎   | 01:26 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 01:33 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▎  | 01:41 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 01:48 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 01:56 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 02:03 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 02:10 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 02:17 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 02:25 Sampling completed
# chain 2 |██████████| 02:25 Sampling completed
# chain 3 |██████████| 02:25 Sampling completed
# chain 4 |██████████| 02:25 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
print(fit_unf.diagnose())
# Out:
# Processing csv files: C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model1-20220403125621_1.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model1-20220403125621_2.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model1-20220403125621_3.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model1-20220403125621_4.csv
#
# Checking sampler transitions treedepth.
# 3994 of 4000 (99.85%) transitions hit the maximum treedepth limit of 10, or 2^10 leapfrog steps.
# Trajectories that are prematurely terminated due to this limit will result in slow exploration.
# For optimal performance, increase this limit.
#
# Checking sampler transitions for divergences.
# 6 of 4000 (0.15%) transitions ended with a divergence.
# These divergent transitions indicate that HMC is not fully able to explore the posterior distribution.
# Try increasing adapt delta closer to 1.
# If this doesn't remove all divergences, try to reparameterize the model.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# The E-BFMI, 0.03, is below the nominal threshold of 0.30 which suggests that HMC may have trouble exploring the target distribution.
# If possible, try to reparameterize the model.
#
# The following parameters had fewer than 0.001 effective draws per transition:
#   beta[1], beta[2], beta[3], beta[4], beta[5], beta[6], beta[7], beta[8], beta[9], beta[10], beta[11], beta[12], beta[13], beta[14], beta[15], beta[16], beta[17], beta[18], beta[19], beta[20], beta[21], beta[22], beta[23], beta[24], beta[25], beta[26], beta[27], beta[28], beta[29], beta[30], beta[31], beta[32], beta[33], beta[34], beta[35], beta[36], beta[37], beta[38], beta[39], beta[40], beta[41], beta[42], beta[43], beta[44], beta[45], beta[46], beta[47], beta[48], beta[49], beta[50], beta[51], beta[52], beta[53], beta[54], beta[55], beta[56], beta[57], beta[58], beta[59], beta[61], beta[62], beta[63], beta[64], beta[65], beta[66], beta[67], beta[68], beta[69], beta[70], beta[71], beta[72], beta[73], beta[74], beta[75], beta[76], beta[77], beta[78], beta[79], beta[80], beta[81], beta[82], beta[83], beta[84], beta[85], beta[86], beta[87], beta[88], beta[89], beta[90], beta[91], beta[92], beta[93], beta[94], beta[95], beta[96], beta[97], beta[98], beta[99], beta[100], beta[101], beta[102], beta[103], beta[104], beta[105], beta[106], beta[107], beta[108], beta[109], beta[110], beta[111], beta[112], beta[113], beta[114], beta[115], beta[116], beta[117], beta[118], beta[120], beta[121], beta[122], beta[123], beta[124], beta[125], beta[126], beta[127], beta[128], beta[129], beta[130], beta[131], beta[132], beta[133], beta[134], beta[135], beta[136], beta[137], beta[138], beta[139], beta[140], beta[141], beta[142], beta[143], beta[145], beta[146], beta[147], beta[148], beta[149], beta[150], beta[151], beta[152], beta[153], beta[154], beta[155], beta[156], beta[157], beta[158], beta[159], beta[160], beta[161], beta[162], beta[163], beta[164], beta[165], beta[166], beta[167], beta[168], beta[169], beta[170], beta[171], beta[173], beta[174], beta[175], beta[176], beta[177], beta[178], beta[179], beta[180], beta[181], beta[182], beta[183], beta[184], beta[185], beta[186], beta[187], beta[188], beta[189], beta[190], beta[191], beta[192], beta[193], beta[194], beta[195], beta[196], beta[197], beta[198], beta[199], beta[200], sigma
# Such low values indicate that the effective sample size estimators may be biased high and actual performance may be substantially lower than quoted.
#
# The following parameters had split R-hat greater than 1.05:
#   beta[1], beta[2], beta[3], beta[4], beta[5], beta[6], beta[7], beta[8], beta[9], beta[10], beta[11], beta[12], beta[13], beta[14], beta[15], beta[16], beta[17], beta[18], beta[19], beta[20], beta[21], beta[22], beta[23], beta[24], beta[25], beta[26], beta[27], beta[28], beta[29], beta[30], beta[31], beta[32], beta[33], beta[34], beta[35], beta[36], beta[37], beta[38], beta[39], beta[40], beta[41], beta[42], beta[43], beta[44], beta[45], beta[46], beta[47], beta[48], beta[49], beta[50], beta[51], beta[52], beta[53], beta[54], beta[55], beta[56], beta[57], beta[58], beta[59], beta[60], beta[61], beta[62], beta[63], beta[64], beta[65], beta[66], beta[67], beta[68], beta[69], beta[70], beta[71], beta[72], beta[73], beta[74], beta[75], beta[76], beta[77], beta[78], beta[79], beta[80], beta[81], beta[82], beta[83], beta[84], beta[85], beta[86], beta[87], beta[88], beta[89], beta[90], beta[91], beta[92], beta[93], beta[94], beta[95], beta[96], beta[97], beta[98], beta[99], beta[100], beta[101], beta[102], beta[103], beta[104], beta[105], beta[106], beta[107], beta[108], beta[109], beta[110], beta[111], beta[112], beta[113], beta[114], beta[115], beta[116], beta[117], beta[118], beta[119], beta[120], beta[121], beta[122], beta[123], beta[124], beta[125], beta[126], beta[127], beta[128], beta[129], beta[130], beta[131], beta[132], beta[133], beta[134], beta[135], beta[136], beta[137], beta[138], beta[139], beta[140], beta[141], beta[142], beta[143], beta[144], beta[145], beta[146], beta[147], beta[148], beta[149], beta[150], beta[151], beta[152], beta[153], beta[154], beta[155], beta[156], beta[157], beta[158], beta[159], beta[160], beta[161], beta[162], beta[163], beta[164], beta[165], beta[166], beta[167], beta[168], beta[169], beta[170], beta[171], beta[172], beta[173], beta[174], beta[175], beta[176], beta[177], beta[178], beta[179], beta[180], beta[181], beta[182], beta[183], beta[184], beta[185], beta[186], beta[187], beta[188], beta[189], beta[190], beta[191], beta[192], beta[193], beta[194], beta[195], beta[196], beta[197], beta[198], beta[199], beta[200], alpha, sigma
# Such high values indicate incomplete mixing and biased estimation.
# You should consider regularizating your model with additional prior information or a more effective parameterization.
#
# Processing complete.

# %% [markdown]
# #### Task 1. Evaluating model
#
# 1. Analyse the diagnosis of the model. What sampling issues occured?
# 2. For each fitted beta coefficient plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated betas (all in the same plot). Compare with true values of beta.
# 3. Substract true values from fitted betas and make the same plot (residues)

# %%
data1 = fit_unf.draws_pd()
data1
# Out:
#           lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -105.9480       0.908778    0.000202         10.0        1023.0
# 1    -110.2270       0.968343    0.000202         10.0        1023.0
# 2    -111.3610       0.990545    0.000202         10.0        1023.0
# 3    -116.3220       0.956476    0.000202         10.0        1023.0
# 4    -110.5340       0.971677    0.000202         10.0        1023.0
# ...        ...            ...         ...          ...           ...
# 3995  -26.9616       0.924372    0.000166         10.0        1023.0
# 3996  -16.3491       0.920538    0.000166         10.0        1023.0
# 3997  -13.5966       0.764615    0.000166         10.0        1023.0
# 3998  -19.1550       0.824743    0.000166         10.0        1023.0
# 3999  -17.9300       0.927235    0.000166         10.0        1023.0
#
#       divergent__  energy__  beta[1]  beta[2]    beta[3]  ...  beta[193]  \
# 0             0.0   203.135 -174.605 -595.491    67.4547  ...   -59.0362
# 1             0.0   199.823 -171.752 -590.918    68.0443  ...   -58.5913
# 2             0.0   207.910 -170.435 -608.053    61.8122  ...   -55.1487
# 3             0.0   224.876 -184.407 -623.190    63.1267  ...   -54.7593
# 4             0.0   220.551 -206.370 -627.853    54.4914  ...   -51.5232
# ...           ...       ...      ...      ...        ...  ...        ...
# 3995          0.0   128.377 -300.498  322.327 -1134.8100  ...  -206.7280
# 3996          0.0   120.605 -297.951  321.875 -1132.5800  ...  -207.1140
# 3997          0.0   115.006 -304.665  323.953 -1142.5800  ...  -205.6840
# 3998          0.0   128.886 -307.013  323.217 -1145.7700  ...  -204.0510
# 3999          0.0   130.340 -297.753  325.365 -1134.7600  ...  -205.8390
#
#       beta[194]  beta[195]  beta[196]  beta[197]  beta[198]  beta[199]  \
# 0      -327.849  -263.7560    544.168    883.644   236.8340    860.838
# 1      -326.872  -264.0780    544.995    882.335   237.5710    859.270
# 2      -328.233  -263.6120    539.176    876.825   235.3090    851.231
# 3      -354.448  -256.5690    536.353    865.691   243.2630    820.039
# 4      -348.223  -254.7620    533.686    867.424   246.8820    841.678
# ...         ...        ...        ...        ...        ...        ...
# 3995    134.099    74.8577    379.329   -287.894   -48.3431    129.541
# 3996    136.190    78.0429    375.887   -285.204   -49.2709    125.097
# 3997    133.491    80.4708    375.843   -288.237   -47.8022    120.470
# 3998    143.034    79.9971    385.648   -294.927   -55.4119    119.578
# 3999    144.488    92.1323    383.514   -300.454   -50.5622    123.238
#
#       beta[200]     alpha     sigma
# 0      112.0200 -1.322030  1.823200
# 1      109.4890 -1.304230  1.809720
# 2      100.0090 -1.295530  1.797610
# 3       77.2167 -1.459660  1.861840
# 4       92.6018 -1.180860  1.841630
# ...         ...       ...       ...
# 3995  -748.1440 -0.532790  0.747480
# 3996  -747.9850 -0.564031  0.754387
# 3997  -757.1030 -0.707668  0.730760
# 3998  -756.4760 -0.566293  0.745233
# 3999  -744.1620 -0.484172  0.744894
#
# [4000 rows x 209 columns]

# %%
def create_medians(data, first_row, length):
    median_min = np.zeros(length)
    for i in range(length):
        median_min[i] = np.min(data.iloc[:, i + first_row])

    median_5 = np.zeros(length)
    for i in range(length):
        median_5[i] = np.quantile(data.iloc[:, i + first_row], 0.05)

    median_25 = np.zeros(length)
    for i in range(length):
        median_25[i] = np.quantile(data.iloc[:, i + first_row], 0.25)

    median_50 = np.zeros(length)
    for i in range(length):
        median_50[i] = np.quantile(data.iloc[:, i + first_row], 0.50)

    median_75 = np.zeros(length)
    for i in range(length):
        median_75[i] = np.quantile(data.iloc[:, i + first_row], 0.75)

    median_95 = np.zeros(length)
    for i in range(length):
        median_95[i] = np.quantile(data.iloc[:, i + first_row], 0.95)

    median_max = np.zeros(length)
    for i in range(length):
        median_max[i] = np.max(data.iloc[:, i + first_row])
    medians = [median_min, median_5, median_25, median_50, median_75, median_95, median_max]
    return medians

def create_predicts(medians, length):
    predicts = []
    X = []
    for median in medians:
        x = (np.linspace(0, length - 1, length)).reshape(-1, 1)
        X.append(x)
        regr = linear_model.LinearRegression()
        regr.fit(x, median)
        predict = regr.predict(x)
        predicts.append(predict)
    return predicts, X

# %%
medians11 = create_medians(data1, 7, 200)
predicts11, X = create_predicts(medians11, 200)

# %%
plt.figure(1, figsize=(12, 10))

for i in range(len(medians11)):
    plt.plot(X[i], medians11[i])
    plt.plot(X[i], predicts11[i])
plt.show()

# %%
residuals1 = data1.iloc[:, 9:] - data_for_inference['X'][:, 0]

# %%
medians12 = create_medians(residuals1, 0, 200)
predicts12, X = create_predicts(medians12, 200)

# %%
plt.figure(2, figsize=(12, 10))

for i in range(len(medians12)):
    plt.plot(X[i], medians12[i])
    plt.plot(X[i], predicts12[i])
plt.show()

# %% [markdown]
# ### Model 2 - Narrow weakly informative prior.
# We try to improve sampling by regularizing the search space with normal priors. This is prior used in ridge regression (but here is the bayesian context)

# %%
model_reg = CmdStanModel(stan_file = 'model2.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
fit_reg = model_reg.sample(data=data_for_inference,seed=seed)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
#
#
#
#
#
# chain 1 |█▎        | 00:03 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
#
#
#
#
# chain 1 |█▊        | 00:07 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
#
#
#
#
#
#
# chain 1 |██▎       | 00:14 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
#
#
#
#
# chain 1 |██▋       | 00:21 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
#
#
# chain 1 |███▏      | 00:28 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
#
#
#
# chain 1 |███▋      | 00:35 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
#
# chain 1 |████▌     | 00:42 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
# chain 1 |█████▉    | 00:48 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
# chain 1 |██████▊   | 00:53 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
# chain 1 |███████▋  | 00:59 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
# chain 1 |████████▋ | 01:04 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
# chain 1 |█████████▌| 01:10 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
# chain 1 |██████████| 01:13 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
# chain 1 |██████████| 01:21 Sampling completed
# chain 2 |██████████| 01:21 Sampling completed
# chain 3 |██████████| 01:21 Sampling completed
# chain 4 |██████████| 01:21 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
print(fit_reg.diagnose())
# Out:
# Processing csv files: C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model2-20220403130231_1.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model2-20220403130231_2.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model2-20220403130231_3.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model2-20220403130231_4.csv
#
# Checking sampler transitions treedepth.
# 1000 of 4000 (25.00%) transitions hit the maximum treedepth limit of 10, or 2^10 leapfrog steps.
# Trajectories that are prematurely terminated due to this limit will result in slow exploration.
# For optimal performance, increase this limit.
#
# Checking sampler transitions for divergences.
# No divergent transitions found.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# The E-BFMI, 0.04, is below the nominal threshold of 0.30 which suggests that HMC may have trouble exploring the target distribution.
# If possible, try to reparameterize the model.
#
# Effective sample size satisfactory.
#
# The following parameters had split R-hat greater than 1.05:
#   sigma
# Such high values indicate incomplete mixing and biased estimation.
# You should consider regularizating your model with additional prior information or a more effective parameterization.
#
# Processing complete.

# %% [markdown]
# #### Task 2. Evaluating model
#
# 1. Analyse the diagnosis of model. Are the sampling problems solved
# 2. For each fitted beta coefficient plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated weight (all in the same plot). Compare with true values of beta.
# 3. Substract true values from fitted betas and make the same plot (residues)

# %%
data2 = fit_reg.draws_pd()
data2
# Out:
#            lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0      0.711479       0.963143    0.009586          9.0         511.0
# 1      7.380870       0.911779    0.009586          9.0         511.0
# 2     -6.903060       0.968520    0.009586          9.0         511.0
# 3    -16.376700       0.943348    0.009586          9.0         511.0
# 4     -1.182800       0.893428    0.009586          9.0         511.0
# ...         ...            ...         ...          ...           ...
# 3995 -31.163700       0.997142    0.004247         10.0        1023.0
# 3996 -32.077400       0.999498    0.004247         10.0        1023.0
# 3997 -41.390200       0.998338    0.004247         10.0        1023.0
# 3998 -52.769300       0.995265    0.004247         10.0        1023.0
# 3999 -56.943100       0.988117    0.004247         10.0        1023.0
#
#       divergent__  energy__   beta[1]   beta[2]   beta[3]  ...  beta[193]  \
# 0             0.0  110.7440 -0.213925  0.738108  0.918532  ...  -1.158070
# 1             0.0   87.5078 -0.259913 -0.684661  0.824767  ...   0.283284
# 2             0.0  102.4520 -1.076950  0.092086 -0.290100  ...   1.083790
# 3             0.0  125.4680 -1.135160  1.006820 -0.252724  ...  -0.493514
# 4             0.0  113.6650 -0.969312 -0.058868 -0.457942  ...  -0.585099
# ...           ...       ...       ...       ...       ...  ...        ...
# 3995          0.0  126.8540  0.895171 -0.257487  0.450064  ...   0.281747
# 3996          0.0   98.4960  0.714114  0.025002 -0.029429  ...   0.634255
# 3997          0.0  128.2280  0.600414  0.021930  0.371785  ...   0.509126
# 3998          0.0  146.8640 -0.936814 -0.680181 -0.123590  ...   0.650051
# 3999          0.0  150.4540 -0.034293  0.514568 -0.847936  ...   0.036513
#
#       beta[194]  beta[195]  beta[196]  beta[197]  beta[198]  beta[199]  \
# 0     -0.591552   0.874517  -0.614819  -0.642880  -0.511446  -1.009920
# 1      0.200740  -0.072894  -0.109971  -0.619316   0.510076   1.184860
# 2     -1.549120  -1.872970  -0.313433   0.074432  -0.642604   0.387021
# 3     -1.830890   0.376334   1.188370  -0.403765   0.690528   0.622825
# 4     -0.953230   1.169630  -0.547339  -0.549836  -0.090253   0.708787
# ...         ...        ...        ...        ...        ...        ...
# 3995   0.608143   1.549410  -0.276083   0.461583   0.145952  -0.080171
# 3996   0.384362   1.221810   0.615320   0.656249   0.448898   0.190148
# 3997   0.603541   0.896665   0.366512  -0.054094   1.506090  -0.232123
# 3998   1.079830  -1.422290   0.810519   0.351876  -0.146800   0.462905
# 3999   0.152850   0.708189   0.673400  -0.176151  -0.039593  -0.296816
#
#       beta[200]     alpha     sigma
# 0      1.035990 -0.092768  0.352440
# 1     -0.135826  1.202600  0.387012
# 2      1.039240 -1.880720  0.349131
# 3      0.460917 -0.037064  0.331368
# 4     -0.207110 -0.727854  0.333513
# ...         ...       ...       ...
# 3995   0.023613  0.859141  0.616129
# 3996   0.422094  1.440940  0.608916
# 3997  -0.075093  1.799760  0.604322
# 3998   0.656098  1.268400  0.523636
# 3999  -0.980132  0.568064  0.644819
#
# [4000 rows x 209 columns]

# %%
medians21 = create_medians(data2, 7, 200)
predicts21, X2 = create_predicts(medians21, 200)

# %%
plt.figure(2, figsize=(12, 10))

for i in range(len(medians21)):
    plt.plot(X2[i], medians21[i])
    plt.plot(X2[i], predicts21[i])
plt.show()

# %%
residuals2 = data2.iloc[:, 9:] - data_for_inference['X'][:, 0]

# %%
medians22 = create_medians(residuals2, 0, 200)
predicts22, X2 = create_predicts(medians22, 200)

# %%
plt.figure(4, figsize=(12, 10))

for i in range(len(medians22)):
    plt.plot(X2[i], medians22[i])
    plt.plot(X2[i], predicts22[i])
plt.show()

# %% [markdown]
# ### Model 3 -  Sparsity enforcing prior
#
# We will now try to enforce shrinking of small parameters using a Laplace prior. This is a prior that is used in Lasso regression. (but here is the bayesian context)

# %%
model_lap = CmdStanModel(stan_file = 'model3.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
fit_lap = model_lap.sample(data=data_for_inference,seed=seed,adapt_delta=0.99,max_treedepth=12) #sampling problematic some parameters have to be adjusted
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:04 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:13 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:21 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
# chain 1 |██▎       | 00:25 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
#
# chain 1 |██▋       | 00:35 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
# chain 1 |███▏      | 00:40 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
# chain 1 |███▋      | 00:48 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
# chain 1 |████      | 00:55 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |████▌     | 01:03 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
#
#
# chain 1 |█████     | 01:18 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
# chain 1 |█████▉    | 01:33 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
#
#
# chain 1 |██████▎   | 01:49 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
#
#
#
# chain 1 |██████▊   | 02:04 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
#
#
#
# chain 1 |███████▎  | 02:19 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
#
#
# chain 1 |███████▋  | 02:34 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
#
#
# chain 1 |████████▏ | 02:48 Iteration: 1500 / 2000 [ 75%]  (Sampling)
# chain 1 |████████▋ | 3:03:00 Iteration: 1600 / 2000 [ 80%]  (Sampling)
# chain 1 |█████████ | 35:16:28 Iteration: 1700 / 2000 [ 85%]  (Sampling)
# chain 1 |█████████▌| 35:16:47 Iteration: 1800 / 2000 [ 90%]  (Sampling)
# chain 1 |██████████| 35:17:01 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
# chain 1 |██████████| 35:17:17 Sampling completed
# chain 2 |██████████| 35:17:17 Sampling completed
# chain 3 |██████████| 35:17:17 Sampling completed
# chain 4 |██████████| 35:17:17 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
print(fit_lap.diagnose())
# Out:
# Processing csv files: C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model3-20220403130414_1.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model3-20220403130414_2.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model3-20220403130414_3.csv, C:\Users\Maciej\AppData\Local\Temp\tmp_fi3_3j6\model3-20220403130414_4.csv
#
# Checking sampler transitions treedepth.
# Treedepth satisfactory for all transitions.
#
# Checking sampler transitions for divergences.
# No divergent transitions found.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# The E-BFMI, 0.03, is below the nominal threshold of 0.30 which suggests that HMC may have trouble exploring the target distribution.
# If possible, try to reparameterize the model.
#
# Effective sample size satisfactory.
#
# The following parameters had split R-hat greater than 1.05:
#   sigma
# Such high values indicate incomplete mixing and biased estimation.
# You should consider regularizating your model with additional prior information or a more effective parameterization.
#
# Processing complete.

# %% [markdown]
# #### Task 3. Evaluating model
#
# 1. Analyse the diagnosis of model. Are the sampling problems solved. Are there any new sampling issues?
# 2. For each fitted beta coefficient plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated weight (all in the same plot). Compare with true values of beta.
# 3. Substract true values from fitted betas and make the same plot (residues)

# %%
data3 = fit_lap.draws_pd()
data3
# Out:
#           lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -174.7900       0.999773    0.003057         11.0        2047.0
# 1    -177.7230       0.988123    0.003057         11.0        2047.0
# 2    -179.2870       0.999938    0.003057         11.0        2047.0
# 3    -196.6570       0.999823    0.003057         11.0        2047.0
# 4    -182.6590       0.991696    0.003057         11.0        2047.0
# ...        ...            ...         ...          ...           ...
# 3995   97.2249       0.485677    0.006619         10.0        1023.0
# 3996   95.7961       0.782615    0.006619         10.0        1023.0
# 3997   92.6414       0.366078    0.006619         10.0        1023.0
# 3998   82.5885       0.344025    0.006619         10.0        1023.0
# 3999   86.7705       0.612001    0.006619         10.0        1023.0
#
#       divergent__  energy__   beta[1]   beta[2]   beta[3]  ...  beta[193]  \
# 0             0.0  269.0590  1.629160 -0.083531 -0.352252  ...  -0.081649
# 1             0.0  278.6150 -0.750307  0.017988  0.078422  ...  -1.117120
# 2             0.0  286.0110  0.606209  0.163591  0.055765  ...   1.195280
# 3             0.0  282.5960  0.033849  0.148905 -0.043599  ...  -0.838915
# 4             0.0  309.8820 -0.107182  0.077201 -0.019451  ...   0.336493
# ...           ...       ...       ...       ...       ...  ...        ...
# 3995          0.0   22.9161  0.411127 -0.255127 -0.102066  ...   0.248549
# 3996          0.0  -14.4046 -0.357673 -0.303655 -0.248184  ...  -0.318057
# 3997          0.0   13.7934  0.590002  0.501337  0.374440  ...   0.732205
# 3998          0.0   18.7478 -0.483742 -0.278220 -0.181088  ...  -0.189271
# 3999          0.0   13.5665  0.712323  0.326197 -0.129105  ...   0.141769
#
#       beta[194]  beta[195]  beta[196]  beta[197]  beta[198]  beta[199]  \
# 0     -1.418340  -0.466395   0.940733  -0.241453  -0.202147   0.135331
# 1     -0.859273  -1.246500  -0.340245  -0.451028   0.020322   0.275974
# 2      1.282470   0.917375   0.333185   0.049793  -0.086722   0.400770
# 3     -1.603410  -0.757750  -0.087416  -0.623182  -0.364300   0.265919
# 4      1.295940   0.097179  -0.261017   0.112152   0.405938   0.344531
# ...         ...        ...        ...        ...        ...        ...
# 3995  -0.333191   1.056460  -0.429238   0.167182   0.062426  -0.768500
# 3996   0.131677  -0.787397   0.135627   0.093029  -0.073414   1.427650
# 3997   0.107010  -0.772490  -0.209921  -0.204749  -0.236327   1.224990
# 3998   0.082600   0.423836  -0.137912  -0.669244  -0.139997  -0.624585
# 3999  -0.224958   0.011442   0.155611   1.225590   0.242801   0.883648
#
#       beta[200]     alpha     sigma
# 0      0.371060 -1.329890  1.210570
# 1      0.825773 -0.426781  1.304230
# 2     -0.842457  1.016610  1.192570
# 3      0.956952 -1.932360  1.160420
# 4     -1.301230 -0.794381  1.322540
# ...         ...       ...       ...
# 3995   0.390410 -0.408634  0.079717
# 3996  -0.180613  0.645272  0.078513
# 3997   1.162710 -0.635387  0.080680
# 3998  -0.723051  0.990026  0.097505
# 3999   1.108580 -1.404350  0.090387
#
# [4000 rows x 209 columns]

# %%
medians3 = create_medians(data3, 7, 200)
predicts3, X3 = create_predicts(medians3, 200)

# %%
plt.figure(3, figsize=(12, 10))

for i in range(len(medians3)):
    plt.plot(X3[i], medians3[i])
    plt.plot(X3[i], predicts3[i])
plt.show()
