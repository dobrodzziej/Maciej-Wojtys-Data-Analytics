# %% [markdown]
# # Lab 4 - Linear models
#
# We focus on models in the form
#
# $$ y ~ \mathrm{Normal}(\alpha+X\beta,\sigma) $$
#
# or in generalized form (generalized linear models)
#
# $$ f(y) ~ \mathrm{Normal}(\alpha+X\beta,\sigma) $$
#
# where $f(y)$ is a link function, for example - logit.

# %%
from cmdstanpy import CmdStanModel


import arviz as az
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import pandas as pd
from seaborn import jointplot
from sklearn import datasets, linear_model

# %% [markdown]
# ## Excercise 1 - modelling height of !Kung people

# %% [markdown]
# ### Normal model - no predictors
# We will try to fit $\mathrm{Normal}(\mu,\sigma)$ distribution to height data. Special case of linear model with $\beta=0$.

# %%
_BASE_URL = "https://raw.githubusercontent.com/rmcelreath/rethinking/Experimental/data"
HOWELL_DATASET_PATH = f"{_BASE_URL}/Howell1.csv"
d = pd.read_csv(HOWELL_DATASET_PATH, sep=';', header=0)
d=d[d.age>=18] #just adults 
d.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
model_ppc=CmdStanModel(stan_file='height_1_ppc.stan')

R = 1000
sim=model_ppc.sample(iter_sampling=R,
                     iter_warmup=0,
                     chains=1,
                     fixed_param=True,
                     seed=29042020,refresh=R)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %% [markdown]
# #### Task 1. Prior predictive checks
#
# 1. Plot histograms of mu, sigma and simulated height.
# 2. Plot a joint distribution of mu and sigma.
# 3. Check if samples are consistent with priors
# 4. Check if observed data is possible to obtain using priors.

# %%
model_1_fit=CmdStanModel(stan_file='height_1_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
fit=model_1_fit.sample(data=dict(N=len(d),
                                   heights=d.height.values),
                         seed=28052020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |███████▋  | 00:00 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
data = fit.draws_pd()
data
# Out:
#          lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -896.475       0.989141    0.879734          3.0           7.0
# 1    -895.714       0.996108    0.879734          2.0           3.0
# 2    -896.343       0.895673    0.879734          2.0           3.0
# 3    -895.404       0.991829    0.879734          2.0           3.0
# 4    -895.849       0.841095    0.879734          2.0           3.0
# ...       ...            ...         ...          ...           ...
# 3995 -895.627       1.000000    0.838787          2.0           3.0
# 3996 -895.727       0.982861    0.838787          1.0           1.0
# 3997 -895.745       0.978395    0.838787          3.0           7.0
# 3998 -895.541       0.984102    0.838787          2.0           7.0
# 3999 -895.239       1.000000    0.838787          2.0           3.0
#
#       divergent__  energy__       mu    sigma   height
# 0             0.0   898.035  155.103  8.10072  151.389
# ...

# %%
mu = fit.stan_variable('mu')
sigma = fit.stan_variable('sigma')
sim_height = fit.stan_variable('height')

# %%
fig, axes = plt.subplots(3, 1, figsize = (8, 24))
axes[0].hist(mu, bins = 15, edgecolor='k')
axes[0].set_title('mu')
axes[0].set_xlabel('value')
axes[0].set_ylabel('no. of draws')
axes[1].hist(sigma, bins = 15, edgecolor='k')
axes[1].set_title('sigma')
axes[1].set_xlabel('value')
axes[1].set_ylabel('no. of draws')
axes[2].hist(sim_height, bins = 15, edgecolor='k')
axes[2].set_title('sim_height')
axes[2].set_xlabel('value')
axes[2].set_ylabel('no. of draws')
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.hist(d.iloc[:, 0], bins = 15, edgecolor='k')
plt.title("original data")
plt.xlabel("values")
plt.ylabel("no. of draws")
plt.show()

# %%
jointplot(data = data, x = "mu", y = "sigma")

# %% [markdown]
# #### Task 2. Model fit and evaluation
#
# 1. Plot a joint distribution of fitted mu and sigma.
# 2. Plot histograms of data and simulated heights and evaluate the quality of model.

# %% [markdown]
# ### Adding predictor to the model - weight
#
# Create column ```c_weight``` in the dataframe containing weights substracted by their mean.

# %%
# weight - mean of the weight

# %%
d['c_weight'] = d['weight']/np.mean(d['weight'])
d
# Out:
#       height     weight   age  male  c_weight
# 0    151.765  47.825606  63.0     1  1.063016
# 1    139.700  36.485807  63.0     0  0.810967
# 2    136.525  31.864838  65.0     0  0.708257
# 3    156.845  53.041914  41.0     1  1.178958
# 4    145.415  41.276872  51.0     0  0.917458
# ..       ...        ...   ...   ...       ...
# 534  162.560  47.031821  27.0     0  1.045373
# 537  142.875  34.246196  31.0     0  0.761188
# 540  162.560  52.163080  31.0     1  1.159425
# 541  156.210  54.062497  21.0     0  1.201643
# 543  158.750  52.531624  68.0     1  1.167616
#
# [352 rows x 5 columns]

# %%
model_ppc=CmdStanModel(stan_file='height_2a_ppc.stan')
R = 1000
data_sim={'N':50, 'weight':np.linspace(d.c_weight.min(),d.c_weight.max(), 50)}
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
data2 = sim.draws_pd()
data2
# Out:
#      lp__  accept_stat__    alpha       beta      sigma  height[1]  height[2]  \
# 0     0.0            0.0  232.163   7.771810  23.208300    246.006    210.799
# 1     0.0            0.0  154.022  -0.067795   0.086958    154.032    153.993
# 2     0.0            0.0  169.461 -11.386400  20.358900    182.356    149.686
# 3     0.0            0.0  158.357  -2.544520   6.415610    163.321    150.562
# 4     0.0            0.0  158.131  16.710200   9.955320    155.541    175.640
# ..    ...            ...      ...        ...        ...        ...        ...
# 995   0.0            0.0  161.753  12.613000   6.017940    185.349    169.808
# 996   0.0            0.0  196.362  12.233800  10.413300    220.472    219.981
# 997   0.0            0.0  172.792  -2.720510  76.805200    131.567    265.111
# 998   0.0            0.0  126.115   9.871600  23.204300    160.671    145.516
# 999   0.0            0.0  203.609  -5.146610  12.390200    191.689    186.772
#
# ...

# %%
jointplot(data = data2, x = "alpha", y = "sigma", kind='reg')
plt.show()

# %%
median = np.zeros(50)
for i in range(50):
    median[i] = np.quantile(data2.iloc[:, i + 5], 0.5)

# %%
x = (np.linspace(np.min(d["weight"]), np.max(d["weight"]))).reshape(-1, 1)

# %%
regr = linear_model.LinearRegression()
regr.fit(x, median)
predict = regr.predict(x)

# %%
plt.plot(np.linspace(np.min(d["weight"]), np.max(d["weight"]), 50), median)
plt.plot(np.linspace(np.min(d["weight"]), np.max(d["weight"]), 50), predict)
plt.xlabel('weight')
plt.ylabel('height')
plt.title('height and weight corellation')
plt.show()

# %% [markdown]
# #### Task 4. Prior predictive checks
# 1. Plot lines for each sampled slope beta and intercept alpha, verify if possible predicted heights are consistent with minimum (0) and maximum (check Wikipedia) heights observed in nature.

# %% [markdown]
# ### Modifying prior
#
# If prior for beta admits negative values, then it makes no sense. Lets change prior to lognormal distribution.

# %%
model_ppc=CmdStanModel(stan_file='height_2b_ppc.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data_sim={'N':50, 'weight':np.linspace(d.c_weight.min(),d.c_weight.max(), 50)}
# data_sim={'N':50, 'weight':np.linspace(0, 100, 50)}

sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
data4 = sim.draws_pd()
data4
# Out:
#      lp__  accept_stat__    alpha       beta      sigma  height[1]  height[2]  \
# 0     0.0            0.0  232.163   7.771810  23.208300    246.006    210.799
# 1     0.0            0.0  154.022  -0.067795   0.086958    154.032    153.993
# 2     0.0            0.0  169.461 -11.386400  20.358900    182.356    149.686
# 3     0.0            0.0  158.357  -2.544520   6.415610    163.321    150.562
# 4     0.0            0.0  158.131  16.710200   9.955320    155.541    175.640
# ..    ...            ...      ...        ...        ...        ...        ...
# 995   0.0            0.0  161.753  12.613000   6.017940    185.349    169.808
# 996   0.0            0.0  196.362  12.233800  10.413300    220.472    219.981
# 997   0.0            0.0  172.792  -2.720510  76.805200    131.567    265.111
# 998   0.0            0.0  126.115   9.871600  23.204300    160.671    145.516
# 999   0.0            0.0  203.609  -5.146610  12.390200    191.689    186.772
#
# ...

# %%
jointplot(data=data4, x = "alpha", y = "beta", kind='reg')
plt.show()

# %%
median_min = np.zeros(50)
for i in range(50):
    median_min[i] = np.quantile(data4.iloc[:, i + 5], 0.01)

median_5 = np.zeros(50)
for i in range(50):
    median_5[i] = np.quantile(data4.iloc[:, i + 5], 0.05)

median_25 = np.zeros(50)
for i in range(50):
    median_25[i] = np.quantile(data4.iloc[:, i + 5], 0.25)

median_50 = np.zeros(50)
for i in range(50):
    median_50[i] = np.quantile(data4.iloc[:, i + 5], 0.50)

median_75 = np.zeros(50)
for i in range(50):
    median_75[i] = np.quantile(data4.iloc[:, i + 5], 0.75)

median_95 = np.zeros(50)
for i in range(50):
    median_95[i] = np.quantile(data4.iloc[:, i + 5], 0.95)

median_max = np.zeros(50)
for i in range(50):
    median_max[i] = np.quantile(data4.iloc[:, i + 5], 0.99)

medians = [median_min, median_5, median_25, median_50, median_75, median_95, median_max]

# %%
predicts = []
X = []
for median in medians:
    x = (np.linspace(np.min(d["weight"]), np.max(d["weight"]), len(median))).reshape(-1, 1)
    X.append(x)
    regr = linear_model.LinearRegression()
    regr.fit(x, median)
    predict = regr.predict(x)
    predicts.append(predict)

# %%
plt.figure(4, figsize=(12, 10))

for i in range(len(medians)):
    plt.plot(X[i], medians[i])
    plt.plot(X[i], predicts[i])

plt.title('weight and height corellation')
plt.xlabel('weight')
plt.ylabel('height')
plt.show()

# %% [markdown]
# On the Wikipedia there is no information about height and weight of !Knug people, can't confirm credibility of resulted data, but height at the level of > 250 [cm] is not very beliveable

# %% [markdown]
# #### Task 5. Prior predictive checks
# 1. Plot lines for each sampled slope beta and intercept alpha, verify if possible predicted heights are consistent with minimum (0) and maximum (check Wikipedia) heights observed in nature.
# 2. For each simulated weight plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated weight (all in the same plot). Compare with observed data. Is observed data possible within the prior model?

# %% [markdown]
# ### Fitting data

# %%
model_2_fit=CmdStanModel(stan_file='height_2_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data_fit = {
    "N": 100, 
    "weight": d['weight'][0:100],
    "heights": d['height'][0:100]
}

fit=model_2_fit.sample(data=data_fit,seed=28052020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
#
#
# chain 1 |██▋       | 00:00 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
# chain 1 |█████     | 00:00 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
# chain 1 |██████▊   | 00:00 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:00 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:01 Iteration: 1800 / 2000 [ 90%]  (Sampling)
# chain 1 |██████████| 00:01 Sampling completed
# chain 2 |██████████| 00:01 Sampling completed
# chain 3 |██████████| 00:01 Sampling completed
# chain 4 |██████████| 00:01 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
data6 = fit.draws_pd()
data6
# Out:
#          lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -228.432       0.913122    0.104094          5.0          31.0
# 1    -225.906       1.000000    0.104094          2.0           3.0
# 2    -225.007       0.897749    0.104094          5.0          31.0
# 3    -225.030       0.883446    0.104094          2.0           3.0
# 4    -225.106       0.989123    0.104094          4.0          31.0
# ...       ...            ...         ...          ...           ...
# 3995 -226.634       0.995978    0.133125          4.0          23.0
# 3996 -224.594       0.981333    0.133125          5.0          47.0
# 3997 -226.693       0.720502    0.133125          2.0           3.0
# 3998 -225.549       0.980910    0.133125          5.0          31.0
# 3999 -225.657       0.923024    0.133125          5.0          39.0
#
#       divergent__  energy__    alpha      beta    sigma  ...  height[91]  \
# 0             0.0   229.792  119.083  0.751989  5.41972  ...     154.540
# ...

# %%
jointplot(data=data6, x = "alpha", y = "beta", kind='reg')
plt.show()

# %% [markdown]
# #### Task 7. Evaluating model
#
# 1. Plot lines for each sampled slope beta and intercept alpha. Verify how uncertainity changes with increasing of sample (N)
# 2. For each simulated weight plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated weight (all in the same plot). Compare with observed data (N points). Is observed data possible within the posterior model? What changes when N increases.

# %%
median_min = np.zeros(100)
for i in range(100):
    median_min[i] = np.quantile(data6.iloc[:, i + 5], 0.01)

median_5 = np.zeros(100)
for i in range(100):
    median_5[i] = np.quantile(data6.iloc[:, i + 5], 0.05)

median_25 = np.zeros(100)
for i in range(100):
    median_25[i] = np.quantile(data6.iloc[:, i + 5], 0.25)

median_50 = np.zeros(100)
for i in range(100):
    median_50[i] = np.quantile(data6.iloc[:, i + 5], 0.50)

median_75 = np.zeros(100)
for i in range(100):
    median_75[i] = np.quantile(data6.iloc[:, i + 5], 0.75)

median_95 = np.zeros(100)
for i in range(100):
    median_95[i] = np.quantile(data6.iloc[:, i + 5], 0.95)

median_max = np.zeros(100)
for i in range(100):
    median_max[i] = np.quantile(data6.iloc[:, i + 5], 0.99)

medians = [median_min, median_5, median_25, median_50, median_75, median_95, median_max]

# %%
predicts = []
X = []
for median in medians:
    x = (np.linspace(np.min(d["weight"]), np.max(d["weight"]), len(median))).reshape(-1, 1)
    X.append(x)
    regr = linear_model.LinearRegression()
    regr.fit(x, median)
    predict = regr.predict(x)
    predicts.append(predict)

# %%
plt.figure(6, figsize=(12, 10))

for i in range(len(medians)):
    # plt.plot(X[i], medians[i])
    plt.plot(X[i], predicts[i])

plt.title('weight and height corellation')
plt.xlabel('weight')
plt.ylabel('height')
plt.show()
